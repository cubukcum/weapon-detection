# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 752.1/752.1 kB 28.3 MB/s eta 0:00:00
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
import wandb
from kaggle_secrets import UserSecretsClient
from ultralytics import YOLO

# %%
user_secrets = UserSecretsClient()

my_secret = user_secrets.get_secret("wandb_api_key") 

wandb.login(key=my_secret)
# Out:
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
sample1 = mpimg.imread('/kaggle/input/weapon-detection/weapon-detection/train/images/ABbframe00274.jpg')
sample2 = mpimg.imread('/kaggle/input/weapon-detection/weapon-detection/test/images/DefenseKnifeAttack0315.jpg')
sample3 = mpimg.imread('/kaggle/input/weapon-detection/weapon-detection/val/images/HBsframe00094.jpg')
plt.imshow(sample1)
plt.show()
plt.imshow(sample2)
plt.show()
plt.imshow(sample3)
plt.show()

# %%
# Load a model
model = YOLO('yolov8n.pt')


# Train the model
results = model.train(data='/kaggle/input/weapon-detection/weapon-detection/data.yaml', epochs=20, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.23M/6.23M [00:00<00:00, 157MB/s]
# Ultralytics YOLOv8.2.4 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# ...

# %%
# Load a model
model = YOLO('/kaggle/working/runs/detect/train/weights/best.pt') 

# Validate the model
metrics = model.val()
# Out:
# Ultralytics YOLOv8.2.4 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# Model summary (fused): 168 layers, 3006818 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /kaggle/input/weapon-detection/weapon-detection/val/labels... 450 images, 0 backgrounds, 0 corrupt: 100%|██████████| 450/450 [00:00<00:00, 624.13it/s]
# val: WARNING ⚠️ Cache directory /kaggle/input/weapon-detection/weapon-detection/val is not writeable, cache not saved.
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 29/29 [00:07<00:00,  4.08it/s]
#                    all        450        450      0.809      0.791      0.862      0.706
#                 pistol        450         50      0.714        0.9      0.873      0.677
#             smartphone        450         58      0.929      0.675      0.902      0.798
#                  knife        450        241      0.912      0.948      0.984      0.683
# ...

# %%
model.predict("/kaggle/input/weapon-detection/weapon-detection/test/images/DSC_0069.jpg",save=True)
# Out:
# image 1/1 /kaggle/input/weapon-detection/weapon-detection/test/images/DSC_0069.jpg: 448x640 1 knife, 52.3ms
# Speed: 2.4ms preprocess, 52.3ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'pistol', 1: 'smartphone', 2: 'knife', 3: 'monedero', 4: 'billete', 5: 'tarjeta'}
#  obb: None
#  orig_img: array([[[ 54,  58,  63],
#          [ 52,  56,  61],
#          [ 51,  55,  60],
#          ...,
#          [115, 112, 107],
#          [112, 109, 101],
#          [113, 110, 102]],
#
#         [[ 51,  54,  62],
#          [ 52,  55,  63],
#          [ 54,  58,  63],
#          ...,
#          [114, 111, 103],
#          [114, 111, 103],
#          [112, 109, 101]],
#
#         [[ 54,  59,  62],
#          [ 54,  59,  62],
#          [ 52,  55,  59],
#          ...,
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np
test = mpimg.imread('/kaggle/working/runs/detect/predict/DSC_0069.jpg')
plt.imshow(test)
